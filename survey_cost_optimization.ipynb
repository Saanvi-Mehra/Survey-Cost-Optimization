# %%
pip install pulp

# %%
import pulp

model = pulp.LpProblem("ProfitMinimizeProblem", pulp.LpMinimize)
x11 = pulp.LpVariable('x11', lowBound=0, cat='Integer')
x12 = pulp.LpVariable('x12', lowBound=0, cat='Integer')
x13 = pulp.LpVariable('x13', lowBound=0, cat='Integer')
x21 = pulp.LpVariable('x21', lowBound=0, cat='Integer')
x22 = pulp.LpVariable('x22', lowBound=0, cat='Integer')
x23 = pulp.LpVariable('x23', lowBound=0, cat='Integer')
x31 = pulp.LpVariable('x31', lowBound=0, cat='Integer')
x32 = pulp.LpVariable('x32', lowBound=0, cat='Integer')
x33 = pulp.LpVariable('x33', lowBound=0, cat='Integer')
x41 = pulp.LpVariable('x41', lowBound=0, cat='Integer')
x42 = pulp.LpVariable('x42', lowBound=0, cat='Integer')
x43 = pulp.LpVariable('x43', lowBound=0, cat='Integer')
model += (
    4.75*x11 + 5.25*x12 + 6.50*x13 +
    6.50*x21 + 5.75*x22 + 7.50*x23 +
    6.50*x31 + 6.25*x32 + 7.50*x33 +
    5.00*x41 + 6.25*x42 + 7.25*x43
)
model += x11 + x12 + x13 >= 400
model += x21 + x22 + x23 >= 550
model += x31 + x32 + x33 >= 300
model += x41 + x42 + x43 >= 300
model += x11 + x21 + x31 + x41 >= 300
model += x12 + x22 + x32 + x42 >= 700
model += x13 + x23 + x33 + x43 >= 400
model += (x11 + x12 + x13 + x21 + x22 + x23 + x31 + x32 + x33 + x41 + x42 + x43) == 2000

model.solve()

print("Optimal value of x11: ",x11.varValue)
print("Optimal value of x12: ", x12.varValue)
print("Optimal value of x13: ", x13.varValue)
print("Optimal value of x21: ", x21.varValue)
print("Optimal value of x22: ", x22.varValue)
print("Optimal value of x23: ", x23.varValue)
print("Optimal value of x31: ", x31.varValue)
print("Optimal value of x32: ", x32.varValue)
print("Optimal value of x33: ", x33.varValue)
print("Optimal value of x41: ", x41.varValue)
print("Optimal value of x42: ", x42.varValue)
print("Optimal value of x43: ", x43.varValue)
print("Minimum Cost: ", pulp.value(model.objective))
# Out:
# Optimal value of x11:  600.0
# Optimal value of x12:  0.0
# Optimal value of x13:  250.0
# Optimal value of x21:  0.0
# Optimal value of x22:  550.0
# Optimal value of x23:  0.0
# Optimal value of x31:  0.0
# Optimal value of x32:  150.0
# Optimal value of x33:  150.0
# Optimal value of x41:  300.0
# Optimal value of x42:  0.0
# Optimal value of x43:  0.0
# Minimum Cost:  11200.0

# %%
import pulp

model = pulp.LpProblem("ProfitMinimizeProblem", pulp.LpMinimize)
x11 = pulp.LpVariable('x11', lowBound=0, cat='Integer')
x12 = pulp.LpVariable('x12', lowBound=0, cat='Integer')
x13 = pulp.LpVariable('x13', lowBound=0, cat='Integer')
x21 = pulp.LpVariable('x21', lowBound=0, cat='Integer')
x22 = pulp.LpVariable('x22', lowBound=0, cat='Integer')
x23 = pulp.LpVariable('x23', lowBound=0, cat='Integer')
x31 = pulp.LpVariable('x31', lowBound=0, cat='Integer')
x32 = pulp.LpVariable('x32', lowBound=0, cat='Integer')
x33 = pulp.LpVariable('x33', lowBound=0, cat='Integer')
x41 = pulp.LpVariable('x41', lowBound=0, cat='Integer')
x42 = pulp.LpVariable('x42', lowBound=0, cat='Integer')
x43 = pulp.LpVariable('x43', lowBound=0, cat='Integer')
model += (
    4.75*x11 + 5.25*x12 + 6.50*x13 +
    6.50*x21 + 5.75*x22 + 7.50*x23 +
    6.50*x31 + 6.25*x32 + 7.50*x33 +
    5.00*x41 + 6.25*x42 + 7.25*x43
)
model += x11 + x12 + x13 >= 400
model += x21 + x22 + x23 >= 550
model += x31 + x32 + x33 >= 300
model += x41 + x42 + x43 >= 300
model += x11 + x21 + x31 + x41 >= 300
model += x12 + x22 + x32 + x42 >= 700
model += x13 + x23 + x33 + x43 >= 400
model += x11 >= 50
model += x12 >= 50
model += x13 >= 50

model += x21 >= 50
model += x22 >= 50
model += x23 >= 50

model += x31 >= 50
model += x32 >= 50
model += x33 >= 50

model += x41 >= 50
model += x42 >= 50
model += x43 >= 50
model += (x11 + x12 + x13 + x21 + x22 + x23 + x31 + x32 + x33 + x41 + x42 + x43) == 2000

model.solve()

print("Optimal value of x11: ",x11.varValue)
print("Optimal value of x12: ", x12.varValue)
print("Optimal value of x13: ", x13.varValue)
print("Optimal value of x21: ", x21.varValue)
print("Optimal value of x22: ", x22.varValue)
print("Optimal value of x23: ", x23.varValue)
print("Optimal value of x31: ", x31.varValue)
print("Optimal value of x32: ", x32.varValue)
print("Optimal value of x33: ", x33.varValue)
print("Optimal value of x41: ", x41.varValue)
print("Optimal value of x42: ", x42.varValue)
print("Optimal value of x43: ", x43.varValue)
print("Minimum Cost: ", pulp.value(model.objective))
# Out:
# Optimal value of x11:  600.0
# Optimal value of x12:  50.0
# Optimal value of x13:  200.0
# Optimal value of x21:  50.0
# Optimal value of x22:  450.0
# Optimal value of x23:  50.0
# Optimal value of x31:  50.0
# Optimal value of x32:  150.0
# Optimal value of x33:  100.0
# Optimal value of x41:  200.0
# Optimal value of x42:  50.0
# Optimal value of x43:  50.0
# Minimum Cost:  11387.5

# %%
import pulp

model = pulp.LpProblem("ProfitMinimizeProblem", pulp.LpMinimize)
x11 = pulp.LpVariable('x11', lowBound=0, cat='Integer')
x12 = pulp.LpVariable('x12', lowBound=0, cat='Integer')
x13 = pulp.LpVariable('x13', lowBound=0, cat='Integer')
x21 = pulp.LpVariable('x21', lowBound=0, cat='Integer')
x22 = pulp.LpVariable('x22', lowBound=0, cat='Integer')
x23 = pulp.LpVariable('x23', lowBound=0, cat='Integer')
x31 = pulp.LpVariable('x31', lowBound=0, cat='Integer')
x32 = pulp.LpVariable('x32', lowBound=0, cat='Integer')
x33 = pulp.LpVariable('x33', lowBound=0, cat='Integer')
x41 = pulp.LpVariable('x41', lowBound=0, cat='Integer')
x42 = pulp.LpVariable('x42', lowBound=0, cat='Integer')
x43 = pulp.LpVariable('x43', lowBound=0, cat='Integer')
model += (
    4.75*x11 + 5.25*x12 + 6.50*x13 +
    6.50*x21 + 5.75*x22 + 7.50*x23 +
    6.50*x31 + 6.25*x32 + 7.50*x33 +
    5.00*x41 + 6.25*x42 + 7.25*x43
)
model += x11 + x12 + x13 >= 400
model += x21 + x22 + x23 >= 550
model += x31 + x32 + x33 >= 300
model += x41 + x42 + x43 >= 300
model += x11 + x21 + x31 + x41 >= 300
model += x12 + x22 + x32 + x42 >= 700
model += x13 + x23 + x33 + x43 >= 400
model += x11 >= 50
model += x12 >= 50
model += x13 >= 50

model += x21 >= 50
model += x22 >= 50
model += x23 >= 50

model += x31 >= 50
model += x32 >= 50
model += x33 >= 50

model += x41 >= 50
model += x42 >= 50
model += x43 >= 50

# Part (d) additional constraints
model += x11 + x12 + x13 <= 600
model += x11 + x21 + x31 + x41 <= 650

model += (x11 + x12 + x13 + x21 + x22 + x23 + x31 + x32 + x33 + x41 + x42 + x43) == 2000

model.solve()

print("Optimal value of x11: ",x11.varValue)
print("Optimal value of x12: ", x12.varValue)
print("Optimal value of x13: ", x13.varValue)
print("Optimal value of x21: ", x21.varValue)
print("Optimal value of x22: ", x22.varValue)
print("Optimal value of x23: ", x23.varValue)
print("Optimal value of x31: ", x31.varValue)
print("Optimal value of x32: ", x32.varValue)
print("Optimal value of x33: ", x33.varValue)
print("Optimal value of x41: ", x41.varValue)
print("Optimal value of x42: ", x42.varValue)
print("Optimal value of x43: ", x43.varValue)
print("Minimum Cost: ", pulp.value(model.objective))
# Out:
# Optimal value of x11:  100.0
# Optimal value of x12:  250.0
# Optimal value of x13:  250.0
# Optimal value of x21:  50.0
# Optimal value of x22:  450.0
# Optimal value of x23:  50.0
# Optimal value of x31:  50.0
# Optimal value of x32:  200.0
# Optimal value of x33:  50.0
# Optimal value of x41:  450.0
# Optimal value of x42:  50.0
# Optimal value of x43:  50.0
# Minimum Cost:  11575.0

# %%
import pulp

model = pulp.LpProblem("ProfitMinimizeProblem", pulp.LpMinimize)
x11 = pulp.LpVariable('x11', lowBound=0, cat='Integer')
x12 = pulp.LpVariable('x12', lowBound=0, cat='Integer')
x13 = pulp.LpVariable('x13', lowBound=0, cat='Integer')
x21 = pulp.LpVariable('x21', lowBound=0, cat='Integer')
x22 = pulp.LpVariable('x22', lowBound=0, cat='Integer')
x23 = pulp.LpVariable('x23', lowBound=0, cat='Integer')
x31 = pulp.LpVariable('x31', lowBound=0, cat='Integer')
x32 = pulp.LpVariable('x32', lowBound=0, cat='Integer')
x33 = pulp.LpVariable('x33', lowBound=0, cat='Integer')
x41 = pulp.LpVariable('x41', lowBound=0, cat='Integer')
x42 = pulp.LpVariable('x42', lowBound=0, cat='Integer')
x43 = pulp.LpVariable('x43', lowBound=0, cat='Integer')
model += (
    6.5*x11 + 6.75*x12 + 7.00*x13 +
    6.50*x21 + 5.75*x22 + 7.50*x23 +
    6.50*x31 + 6.25*x32 + 7.50*x33 +
    5.00*x41 + 6.25*x42 + 7.25*x43
)
model += x11 + x12 + x13 >= 400
model += x21 + x22 + x23 >= 550
model += x31 + x32 + x33 >= 300
model += x41 + x42 + x43 >= 300
model += x11 + x21 + x31 + x41 >= 300
model += x12 + x22 + x32 + x42 >= 700
model += x13 + x23 + x33 + x43 >= 400
model += x11 >= 50
model += x12 >= 50
model += x13 >= 50

model += x21 >= 50
model += x22 >= 50
model += x23 >= 50

model += x31 >= 50
model += x32 >= 50
model += x33 >= 50

model += x41 >= 50
model += x42 >= 50
model += x43 >= 50

# Part (d) additional constraints
model += x11 + x12 + x13 <= 600
model += x11 + x21 + x31 + x41 <= 650

model += (x11 + x12 + x13 + x21 + x22 + x23 + x31 + x32 + x33 + x41 + x42 + x43) == 2000

model.solve()

print("Optimal value of x11: ",x11.varValue)
print("Optimal value of x12: ", x12.varValue)
print("Optimal value of x13: ", x13.varValue)
print("Optimal value of x21: ", x21.varValue)
print("Optimal value of x22: ", x22.varValue)
print("Optimal value of x23: ", x23.varValue)
print("Optimal value of x31: ", x31.varValue)
print("Optimal value of x32: ", x32.varValue)
print("Optimal value of x33: ", x33.varValue)
print("Optimal value of x41: ", x41.varValue)
print("Optimal value of x42: ", x42.varValue)
print("Optimal value of x43: ", x43.varValue)
print("Minimum Cost: ", pulp.value(model.objective))
# Out:
# Optimal value of x11:  50.0
# Optimal value of x12:  100.0
# Optimal value of x13:  250.0
# Optimal value of x21:  50.0
# Optimal value of x22:  600.0
# Optimal value of x23:  50.0
# Optimal value of x31:  50.0
# Optimal value of x32:  200.0
# Optimal value of x33:  50.0
# Optimal value of x41:  500.0
# Optimal value of x42:  50.0
# Optimal value of x43:  50.0
# Minimum Cost:  12025.0

# %%
import pulp

model = pulp.LpProblem("ProfitMinimizeProblem", pulp.LpMinimize)
x11 = pulp.LpVariable('x11', lowBound=0, cat='Integer')
x12 = pulp.LpVariable('x12', lowBound=0, cat='Integer')
x13 = pulp.LpVariable('x13', lowBound=0, cat='Integer')
x21 = pulp.LpVariable('x21', lowBound=0, cat='Integer')
x22 = pulp.LpVariable('x22', lowBound=0, cat='Integer')
x23 = pulp.LpVariable('x23', lowBound=0, cat='Integer')
x31 = pulp.LpVariable('x31', lowBound=0, cat='Integer')
x32 = pulp.LpVariable('x32', lowBound=0, cat='Integer')
x33 = pulp.LpVariable('x33', lowBound=0, cat='Integer')
x41 = pulp.LpVariable('x41', lowBound=0, cat='Integer')
x42 = pulp.LpVariable('x42', lowBound=0, cat='Integer')
x43 = pulp.LpVariable('x43', lowBound=0, cat='Integer')
model += (
    6.5*x11 + 6.75*x12 + 7.00*x13 +
    6.50*x21 + 5.75*x22 + 7.50*x23 +
    6.50*x31 + 6.25*x32 + 7.50*x33 +
    5.00*x41 + 6.25*x42 + 7.25*x43
)
model += x11 + x12 + x13 == 500
model += x21 + x22 + x23 == 700
model += x31 + x32 + x33 == 400
model += x41 + x42 + x43 == 400
model += x11 + x21 + x31 + x41 == 400
model += x12 + x22 + x32 + x42 == 1000
model += x13 + x23 + x33 + x43 == 600
model += x11 >= 50
model += x12 >= 50
model += x13 >= 50

model += x21 >= 50
model += x22 >= 50
model += x23 >= 50

model += x31 >= 50
model += x32 >= 50
model += x33 >= 50

model += x41 >= 50
model += x42 >= 50
model += x43 >= 50

# Part (d) additional constraints
model += x11 + x12 + x13 <= 600
model += x11 + x21 + x31 + x41 <= 650

model += (x11 + x12 + x13 + x21 + x22 + x23 + x31 + x32 + x33 + x41 + x42 + x43) == 2000

model.solve()

print("Optimal value of x11: ",x11.varValue)
print("Optimal value of x12: ", x12.varValue)
print("Optimal value of x13: ", x13.varValue)
print("Optimal value of x21: ", x21.varValue)
print("Optimal value of x22: ", x22.varValue)
print("Optimal value of x23: ", x23.varValue)
print("Optimal value of x31: ", x31.varValue)
print("Optimal value of x32: ", x32.varValue)
print("Optimal value of x33: ", x33.varValue)
print("Optimal value of x41: ", x41.varValue)
print("Optimal value of x42: ", x42.varValue)
print("Optimal value of x43: ", x43.varValue)
print("Minimum Cost: ", pulp.value(model.objective))
# Out:
# Optimal value of x11:  50.0
# Optimal value of x12:  50.0
# Optimal value of x13:  400.0
# Optimal value of x21:  50.0
# Optimal value of x22:  600.0
# Optimal value of x23:  50.0
# Optimal value of x31:  50.0
# Optimal value of x32:  300.0
# Optimal value of x33:  50.0
# Optimal value of x41:  250.0
# Optimal value of x42:  50.0
# Optimal value of x43:  100.0
# Minimum Cost:  12475.0
